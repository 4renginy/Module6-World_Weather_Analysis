# %%
# Import the requests library.
import requests

# Import the API key.
from configw import weather_api_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import g_key
import time

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#If the city is unique, then we will add it to the cities list.    
    if city not in cities:
            cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description=city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description":city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | baturaja
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | saint-augustin
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | susangerd
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | ostrovnoy
# Processing Record 12 of Set 1 | el carmen
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | morant bay
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | lagoa
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | kavieng
# Processing Record 23 of Set 1 | ahipara
# Processing Record 24 of Set 1 | adre
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | moron
# Processing Record 28 of Set 1 | mandalgovi
# Processing Record 29 of Set 1 | sandwick
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | beyneu
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | ardakan
# Processing Record 34 of Set 1 | leningradskiy
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | chute-aux-outardes
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | sinjar
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | udachnyy
# Processing Record 44 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | luganville
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | buin
# Processing Record 2 of Set 2 | port-gentil
# Processing Record 3 of Set 2 | guadalajara
# Processing Record 4 of Set 2 | kungurtug
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | tarko-sale
# Processing Record 7 of Set 2 | hegang
# Processing Record 8 of Set 2 | motril
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | osmena
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | acajutla
# Processing Record 15 of Set 2 | san cristobal
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | pacific grove
# Processing Record 19 of Set 2 | yumen
# Processing Record 20 of Set 2 | sladkovo
# Processing Record 21 of Set 2 | chardara
# Processing Record 22 of Set 2 | klaksvik
# Processing Record 23 of Set 2 | blois
# Processing Record 24 of Set 2 | monteagudo
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | esperance
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | bongandanga
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | mackay
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | ola
# Processing Record 36 of Set 2 | wyndham
# Processing Record 37 of Set 2 | mabaruma
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 2 | la rioja
# Processing Record 41 of Set 2 | sur
# Processing Record 42 of Set 2 | takoradi
# Processing Record 43 of Set 2 | bahia blanca
# Processing Record 44 of Set 2 | half moon bay
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | chateau-gontier
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | cap-aux-meules
# Processing Record 49 of Set 2 | isangel
# Processing Record 50 of Set 2 | punta arenas
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | vierzon
# Processing Record 4 of Set 3 | kalabo
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | daru
# Processing Record 8 of Set 3 | goreloye
# Processing Record 9 of Set 3 | carutapera
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | saravan
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 3 | brae
# Processing Record 17 of Set 3 | vestmanna
# Processing Record 18 of Set 3 | grand gaube
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | keti bandar
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | montepuez
# Processing Record 23 of Set 3 | paamiut
# Processing Record 24 of Set 3 | morlaix
# Processing Record 25 of Set 3 | labuhan
# Processing Record 26 of Set 3 | panguna
# Processing Record 27 of Set 3 | kutum
# Processing Record 28 of Set 3 | bambous virieux
# Processing Record 29 of Set 3 | padang
# Processing Record 30 of Set 3 | sinnamary
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | mwinilunga
# Processing Record 33 of Set 3 | berlevag
# Processing Record 34 of Set 3 | ferrol
# Processing Record 35 of Set 3 | vanimo
# Processing Record 36 of Set 3 | batagay-alyta
# Processing Record 37 of Set 3 | rio grande
# Processing Record 38 of Set 3 | soyo
# Processing Record 39 of Set 3 | paraopeba
# Processing Record 40 of Set 3 | barmer
# Processing Record 41 of Set 3 | ongandjera
# Processing Record 42 of Set 3 | chicama
# Processing Record 43 of Set 3 | victoria
# Processing Record 44 of Set 3 | mercedes
# Processing Record 45 of Set 3 | bilma
# Processing Record 46 of Set 3 | el vigia
# Processing Record 47 of Set 3 | utica
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | nanga eboko
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | hilo
# Processing Record 4 of Set 4 | semnan
# Processing Record 5 of Set 4 | marystown
# Processing Record 6 of Set 4 | nanakuli
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | izumo
# Processing Record 9 of Set 4 | pyatnitskoye
# Processing Record 10 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 4 | tortoli
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | navoi
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 4 | pevek
# Processing Record 17 of Set 4 | santa rosa
# Processing Record 18 of Set 4 | saskylakh
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | constitucion
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | kalemie
# Processing Record 24 of Set 4 | menongue
# Processing Record 25 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 4 | kenai
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | honningsvag
# Processing Record 29 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 30 of Set 4 | leesburg
# Processing Record 31 of Set 4 | nefteyugansk
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | huilong
# Processing Record 34 of Set 4 | geraldton
# Processing Record 35 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | carauari
# Processing Record 38 of Set 4 | husainabad
# Processing Record 39 of Set 4 | jaguarari
# Processing Record 40 of Set 4 | barra do garcas
# Processing Record 41 of Set 4 | topolevo
# Processing Record 42 of Set 4 | yenagoa
# Processing Record 43 of Set 4 | egvekinot
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | laela
# Processing Record 46 of Set 4 | tautira
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | north bend
# Processing Record 49 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | ixtapa
# Processing Record 3 of Set 5 | bani
# Processing Record 4 of Set 5 | nago
# Processing Record 5 of Set 5 | moose factory
# Processing Record 6 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | waitati
# Processing Record 10 of Set 5 | bressanone
# Processing Record 11 of Set 5 | majene
# Processing Record 12 of Set 5 | owando
# Processing Record 13 of Set 5 | coahuayana
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | nioro
# Processing Record 17 of Set 5 | ushirombo
# Processing Record 18 of Set 5 | dunedin
# Processing Record 19 of Set 5 | dakar
# Processing Record 20 of Set 5 | charleston
# Processing Record 21 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 5 | byron bay
# Processing Record 23 of Set 5 | barahona
# Processing Record 24 of Set 5 | dogondoutchi
# Processing Record 25 of Set 5 | saldanha
# Processing Record 26 of Set 5 | kapaa
# Processing Record 27 of Set 5 | hami
# Processing Record 28 of Set 5 | kloulklubed
# Processing Record 29 of Set 5 | tongliao
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | abonnema
# Processing Record 33 of Set 5 | ghugus
# Processing Record 34 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 5 | malakal
# Processing Record 36 of Set 5 | portland
# Processing Record 37 of Set 5 | walvis bay
# Processing Record 38 of Set 5 | vardo
# Processing Record 39 of Set 5 | derzhavinsk
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | puerto escondido
# Processing Record 42 of Set 5 | guanhaes
# Processing Record 43 of Set 5 | sorland
# Processing Record 44 of Set 5 | neyshabur
# Processing Record 45 of Set 5 | murgab
# Processing Record 46 of Set 5 | sidi ali
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | boda
# Processing Record 50 of Set 5 | volot
# Processing Record 1 of Set 6 | bhilwara
# Processing Record 2 of Set 6 | airai
# Processing Record 3 of Set 6 | inhambane
# Processing Record 4 of Set 6 | pangai
# Processing Record 5 of Set 6 | beira
# Processing Record 6 of Set 6 | yiyang
# Processing Record 7 of Set 6 | dunmore town
# Processing Record 8 of Set 6 | linxia
# Processing Record 9 of Set 6 | samarai
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | vera cruz
# Processing Record 13 of Set 6 | vanavara
# Processing Record 14 of Set 6 | jamestown
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | galle
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | hongjiang
# Processing Record 19 of Set 6 | avera
# Processing Record 20 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 6 | ankazobe
# Processing Record 22 of Set 6 | moree
# Processing Record 23 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 6 | tomatlan
# Processing Record 25 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 6 | nipawin
# Processing Record 27 of Set 6 | barcelona
# Processing Record 28 of Set 6 | faya
# Processing Record 29 of Set 6 | ikom
# Processing Record 30 of Set 6 | safaga
# Processing Record 31 of Set 6 | pyaozerskiy
# Processing Record 32 of Set 6 | sawtell
# Processing Record 33 of Set 6 | miranda
# Processing Record 34 of Set 6 | alofi
# Processing Record 35 of Set 6 | taraza
# Processing Record 36 of Set 6 | kruisfontein
# Processing Record 37 of Set 6 | wilmington
# Processing Record 38 of Set 6 | talnakh
# Processing Record 39 of Set 6 | ajdabiya
# Processing Record 40 of Set 6 | parakai
# Processing Record 41 of Set 6 | roma
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | karoi
# Processing Record 44 of Set 6 | tignere
# Processing Record 45 of Set 6 | amapa
# Processing Record 46 of Set 6 | doha
# Processing Record 47 of Set 6 | canutama
# Processing Record 48 of Set 6 | namatanai
# Processing Record 49 of Set 6 | jieshi
# Processing Record 50 of Set 6 | rio gallegos
# Processing Record 1 of Set 7 | simao
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | tasiilaq
# Processing Record 4 of Set 7 | porto murtinho
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | athabasca
# Processing Record 7 of Set 7 | villaviciosa
# Processing Record 8 of Set 7 | petrovsk
# Processing Record 9 of Set 7 | kingisepp
# Processing Record 10 of Set 7 | cap malheureux
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | polovinnoye
# Processing Record 13 of Set 7 | corinto
# Processing Record 14 of Set 7 | banda aceh
# Processing Record 15 of Set 7 | ciudad bolivar
# Processing Record 16 of Set 7 | cedar city
# Processing Record 17 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 7 | kuala selangor
# Processing Record 19 of Set 7 | uyuni
# Processing Record 20 of Set 7 | baykit
# Processing Record 21 of Set 7 | geilo
# Processing Record 22 of Set 7 | aborlan
# Processing Record 23 of Set 7 | beshpagir
# Processing Record 24 of Set 7 | christchurch
# Processing Record 25 of Set 7 | mogadishu
# Processing Record 26 of Set 7 | jardim
# Processing Record 27 of Set 7 | samfya
# Processing Record 28 of Set 7 | dandong
# Processing Record 29 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 7 | baiyin
# Processing Record 31 of Set 7 | risod
# Processing Record 32 of Set 7 | duzce
# Processing Record 33 of Set 7 | dudinka
# Processing Record 34 of Set 7 | mobaye
# Processing Record 35 of Set 7 | georgetown
# Processing Record 36 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 7 | nusaybin
# Processing Record 38 of Set 7 | pitimbu
# Processing Record 39 of Set 7 | chufarovo
# Processing Record 40 of Set 7 | asheboro
# Processing Record 41 of Set 7 | liman
# Processing Record 42 of Set 7 | bantogon
# Processing Record 43 of Set 7 | cockburn town
# Processing Record 44 of Set 7 | maceio
# Processing Record 45 of Set 7 | sisimiut
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | vestmannaeyjar
# Processing Record 48 of Set 7 | margate
# Processing Record 49 of Set 7 | phimai
# Processing Record 50 of Set 7 | lompoc
# Processing Record 1 of Set 8 | kulhudhuffushi
# Processing Record 2 of Set 8 | cayenne
# Processing Record 3 of Set 8 | yar-sale
# Processing Record 4 of Set 8 | deputatskiy
# Processing Record 5 of Set 8 | mudgee
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | poum
# Processing Record 8 of Set 8 | nantucket
# Processing Record 9 of Set 8 | hasaki
# Processing Record 10 of Set 8 | gat
# Processing Record 11 of Set 8 | ihosy
# Processing Record 12 of Set 8 | tokmak
# Processing Record 13 of Set 8 | tommot
# Processing Record 14 of Set 8 | lethem
# Processing Record 15 of Set 8 | ozinki
# Processing Record 16 of Set 8 | potosi
# Processing Record 17 of Set 8 | mount gambier
# Processing Record 18 of Set 8 | jaciara
# Processing Record 19 of Set 8 | ahuimanu
# Processing Record 20 of Set 8 | chumikan
# Processing Record 21 of Set 8 | westport
# Processing Record 22 of Set 8 | dinguiraye
# Processing Record 23 of Set 8 | ilulissat
# Processing Record 24 of Set 8 | henties bay
# Processing Record 25 of Set 8 | ngunguru
# Processing Record 26 of Set 8 | filadelfia
# Processing Record 27 of Set 8 | haines junction
# Processing Record 28 of Set 8 | kimbe
# Processing Record 29 of Set 8 | lamu
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | emba
# Processing Record 32 of Set 8 | yeppoon
# Processing Record 33 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 34 of Set 8 | ljutomer
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | siderno
# Processing Record 37 of Set 8 | lerwick
# Processing Record 38 of Set 8 | neiafu
# Processing Record 39 of Set 8 | dieppe
# Processing Record 40 of Set 8 | pemangkat
# Processing Record 41 of Set 8 | sitka
# Processing Record 42 of Set 8 | puerto plata
# Processing Record 43 of Set 8 | ancud
# Processing Record 44 of Set 8 | sishui
# Processing Record 45 of Set 8 | passo de camaragibe
# Processing Record 46 of Set 8 | riviere-au-renard
# Processing Record 47 of Set 8 | neringa
# Processing Record 48 of Set 8 | akyab
# Processing Record 49 of Set 8 | ponta do sol
# Processing Record 50 of Set 8 | mount isa
# Processing Record 1 of Set 9 | christiansburg
# Processing Record 2 of Set 9 | cam ranh
# Processing Record 3 of Set 9 | fukue
# Processing Record 4 of Set 9 | acarau
# Processing Record 5 of Set 9 | magadi
# Processing Record 6 of Set 9 | vester hassing
# Processing Record 7 of Set 9 | sabinopolis
# Processing Record 8 of Set 9 | bathsheba
# Processing Record 9 of Set 9 | hobyo
# Processing Record 10 of Set 9 | sohag
# Processing Record 11 of Set 9 | amalapuram
# Processing Record 12 of Set 9 | mogzon
# Processing Record 13 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 9 | abu dhabi
# Processing Record 15 of Set 9 | mon
# Processing Record 16 of Set 9 | port hedland
# Processing Record 17 of Set 9 | nanfeng
# Processing Record 18 of Set 9 | pochutla
# Processing Record 19 of Set 9 | talaya
# Processing Record 20 of Set 9 | yichang
# Processing Record 21 of Set 9 | nhulunbuy
# Processing Record 22 of Set 9 | kalmunai
# Processing Record 23 of Set 9 | unhel
# Processing Record 24 of Set 9 | calvinia
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | najran
# Processing Record 27 of Set 9 | mastic beach
# Processing Record 28 of Set 9 | axim
# Processing Record 29 of Set 9 | belgrade
# Processing Record 30 of Set 9 | chimbote
# Processing Record 31 of Set 9 | sao joao da barra
# Processing Record 32 of Set 9 | maues
# Processing Record 33 of Set 9 | elko
# Processing Record 34 of Set 9 | fortuna
# Processing Record 35 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 9 | pirovskoye
# Processing Record 37 of Set 9 | roebourne
# Processing Record 38 of Set 9 | chibombo
# Processing Record 39 of Set 9 | toledo
# Processing Record 40 of Set 9 | khoy
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | olkhovka
# Processing Record 43 of Set 9 | campos sales
# Processing Record 44 of Set 9 | coquimbo
# Processing Record 45 of Set 9 | hemnesberget
# Processing Record 46 of Set 9 | leh
# Processing Record 47 of Set 9 | aitape
# Processing Record 48 of Set 9 | les cayes
# Processing Record 49 of Set 9 | abha
# Processing Record 50 of Set 9 | juba
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | mahina
# Processing Record 3 of Set 10 | lasa
# Processing Record 4 of Set 10 | namtsy
# Processing Record 5 of Set 10 | koungheul
# Processing Record 6 of Set 10 | aras
# Processing Record 7 of Set 10 | erzin
# Processing Record 8 of Set 10 | kathmandu
# Processing Record 9 of Set 10 | gravdal
# Processing Record 10 of Set 10 | phra pradaeng
# Processing Record 11 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 12 of Set 10 | adrar
# Processing Record 13 of Set 10 | kiunga
# Processing Record 14 of Set 10 | nanortalik
# Processing Record 15 of Set 10 | upernavik
# Processing Record 16 of Set 10 | forio
# Processing Record 17 of Set 10 | kota
# Processing Record 18 of Set 10 | nabire
# Processing Record 19 of Set 10 | tulun
# Processing Record 20 of Set 10 | nyurba
# Processing Record 21 of Set 10 | guerrero negro
# Processing Record 22 of Set 10 | sorong
# Processing Record 23 of Set 10 | sangueya
# Processing Record 24 of Set 10 | miri
# Processing Record 25 of Set 10 | skelleftea
# Processing Record 26 of Set 10 | vila velha
# Processing Record 27 of Set 10 | tabas
# Processing Record 28 of Set 10 | vagur
# Processing Record 29 of Set 10 | idar
# Processing Record 30 of Set 10 | tadine
# Processing Record 31 of Set 10 | isla pucu
# Processing Record 32 of Set 10 | cururupu
# Processing Record 33 of Set 10 | cody
# Processing Record 34 of Set 10 | virginia beach
# Processing Record 35 of Set 10 | tessalit
# Processing Record 36 of Set 10 | schwarzenbach
# Processing Record 37 of Set 10 | vila
# Processing Record 38 of Set 10 | tadpatri
# Processing Record 39 of Set 10 | lodja
# Processing Record 40 of Set 10 | kaikalur
# Processing Record 41 of Set 10 | port augusta
# Processing Record 42 of Set 10 | konibodom
# Processing Record 43 of Set 10 | novobirilyussy
# Processing Record 44 of Set 10 | kempsey
# Processing Record 45 of Set 10 | bestobe
# Processing Record 46 of Set 10 | emporia
# Processing Record 47 of Set 10 | chernyshevskiy
# Processing Record 48 of Set 10 | xuanhua
# Processing Record 49 of Set 10 | marsa matruh
# Processing Record 50 of Set 10 | great falls
# Processing Record 1 of Set 11 | bonfim
# Processing Record 2 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 11 | broome
# Processing Record 4 of Set 11 | praya
# Processing Record 5 of Set 11 | new delhi
# Processing Record 6 of Set 11 | timmins
# Processing Record 7 of Set 11 | shenjiamen
# Processing Record 8 of Set 11 | hun
# Processing Record 9 of Set 11 | vytegra
# Processing Record 10 of Set 11 | mount hagen
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | gunjur
# Processing Record 13 of Set 11 | parvatipuram
# Processing Record 14 of Set 11 | fairbanks
# Processing Record 15 of Set 11 | tirlyanskiy
# Processing Record 16 of Set 11 | karymskoye
# Processing Record 17 of Set 11 | pokhara
# Processing Record 18 of Set 11 | puerto del rosario
# Processing Record 19 of Set 11 | belaya gora
# Processing Record 20 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 11 | ndioum
# Processing Record 22 of Set 11 | maxixe
# Processing Record 23 of Set 11 | paita
# Processing Record 24 of Set 11 | pacasmayo
# Processing Record 25 of Set 11 | necochea
# Processing Record 26 of Set 11 | zhangjiakou
# Processing Record 27 of Set 11 | porterville
# Processing Record 28 of Set 11 | raudeberg
# Processing Record 29 of Set 11 | katsuura
# Processing Record 30 of Set 11 | sao joao evangelista
# Processing Record 31 of Set 11 | maldonado
# Processing Record 32 of Set 11 | kabarnet
# Processing Record 33 of Set 11 | zhanaozen
# Processing Record 34 of Set 11 | yeniseysk
# Processing Record 35 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 11 | lumby
# Processing Record 37 of Set 11 | carballo
# Processing Record 38 of Set 11 | sarangani
# Processing Record 39 of Set 11 | mahanoro
# Processing Record 40 of Set 11 | fayaoue
# Processing Record 41 of Set 11 | amherst
# Processing Record 42 of Set 11 | chingirlau
# Processing Record 43 of Set 11 | okhotsk
# Processing Record 44 of Set 11 | kurumkan
# Processing Record 45 of Set 11 | rio claro
# Processing Record 46 of Set 11 | warrington
# Processing Record 47 of Set 11 | okha
# Processing Record 48 of Set 11 | agogo
# Processing Record 49 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 11 | mareeba
# Processing Record 1 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 2 of Set 12 | sarai
# Processing Record 3 of Set 12 | general pico
# Processing Record 4 of Set 12 | bilibino
# Processing Record 5 of Set 12 | buala
# Processing Record 6 of Set 12 | plyussa
# Processing Record 7 of Set 12 | meulaboh
# Processing Record 8 of Set 12 | carman
# Processing Record 9 of Set 12 | vostok
# Processing Record 10 of Set 12 | aksarka
# Processing Record 11 of Set 12 | shache
# Processing Record 12 of Set 12 | rochegda
# Processing Record 13 of Set 12 | bam
# Processing Record 14 of Set 12 | teguldet
# Processing Record 15 of Set 12 | san policarpo
# Processing Record 16 of Set 12 | banfora
# Processing Record 17 of Set 12 | edd
# Processing Record 18 of Set 12 | boguchany
# Processing Record 19 of Set 12 | mezen
# Processing Record 20 of Set 12 | karratha
# Processing Record 21 of Set 12 | pembroke
# Processing Record 22 of Set 12 | dzhebariki-khaya
# Processing Record 23 of Set 12 | sucua
# Processing Record 24 of Set 12 | methoni
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | maneromango
# Processing Record 27 of Set 12 | clonakilty
# Processing Record 28 of Set 12 | san rafael
# Processing Record 29 of Set 12 | giyani
# Processing Record 30 of Set 12 | rapar
# Processing Record 31 of Set 12 | mamit
# Processing Record 32 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 12 | san juan
# Processing Record 35 of Set 12 | berberati
# Processing Record 36 of Set 12 | aranos
# Processing Record 37 of Set 12 | talipparamba
# Processing Record 38 of Set 12 | tilichiki
# Processing Record 39 of Set 12 | inongo
# Processing Record 40 of Set 12 | banepa
# Processing Record 41 of Set 12 | nuuk
# Processing Record 42 of Set 12 | chimoio
# Processing Record 43 of Set 12 | solnechnyy
# Processing Record 44 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 45 of Set 12 | palmer
# Processing Record 46 of Set 12 | katherine
# Processing Record 47 of Set 12 | paro
# Processing Record 48 of Set 12 | bandarbeyla
# Processing Record 49 of Set 12 | tura
# Processing Record 50 of Set 12 | sulz
# Processing Record 1 of Set 13 | san patricio
# Processing Record 2 of Set 13 | grants pass
# Processing Record 3 of Set 13 | villazon
# Processing Record 4 of Set 13 | alice springs
# Processing Record 5 of Set 13 | genhe
# Processing Record 6 of Set 13 | korla
# Processing Record 7 of Set 13 | marzuq
# Processing Record 8 of Set 13 | ambon
# Processing Record 9 of Set 13 | mayo
# Processing Record 10 of Set 13 | trapani
# Processing Record 11 of Set 13 | sann
# Processing Record 12 of Set 13 | stephenville
# Processing Record 13 of Set 13 | zhezkazgan
# Processing Record 14 of Set 13 | esna
# Processing Record 15 of Set 13 | marawi
# Processing Record 16 of Set 13 | tupik
# Processing Record 17 of Set 13 | awbari
# Processing Record 18 of Set 13 | richards bay
# Processing Record 19 of Set 13 | bacolod
# Processing Record 20 of Set 13 | rome
# Processing Record 21 of Set 13 | kizema
# Processing Record 22 of Set 13 | kibondo
# Processing Record 23 of Set 13 | acapulco
# Processing Record 24 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 13 | kamina
# Processing Record 26 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 13 | dukhovshchina
# Processing Record 28 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 13 | villamartin
# Processing Record 30 of Set 13 | taltal
# Processing Record 31 of Set 13 | huarmey
# Processing Record 32 of Set 13 | west odessa
# Processing Record 33 of Set 13 | manjacaze
# Processing Record 34 of Set 13 | lorengau
# Processing Record 35 of Set 13 | araouane
# Processing Record 36 of Set 13 | tha muang
# Processing Record 37 of Set 13 | monteiro
# Processing Record 38 of Set 13 | iroquois falls
# Processing Record 39 of Set 13 | coihaique
# Processing Record 40 of Set 13 | high prairie
# Processing Record 41 of Set 13 | freeport
# Processing Record 42 of Set 13 | troy
# Processing Record 43 of Set 13 | askino
# Processing Record 44 of Set 13 | aleksandrovskoye
# Processing Record 45 of Set 13 | karatu
# Processing Record 46 of Set 13 | san pedro
# Processing Record 47 of Set 13 | mus
# Processing Record 48 of Set 13 | kupang
# Processing Record 49 of Set 13 | tambopata
# Processing Record 50 of Set 13 | olafsvik
# Processing Record 1 of Set 14 | asyut
# Processing Record 2 of Set 14 | chirongui
# Processing Record 3 of Set 14 | chipinge
# Processing Record 4 of Set 14 | am timan
# Processing Record 5 of Set 14 | iqaluit
# Processing Record 6 of Set 14 | svetlogorsk
# Processing Record 7 of Set 14 | solvychegodsk
# Processing Record 8 of Set 14 | magalia
# Processing Record 9 of Set 14 | salta
# Processing Record 10 of Set 14 | komatipoort
# Processing Record 11 of Set 14 | tiksi
# Processing Record 12 of Set 14 | bushehr
# Processing Record 13 of Set 14 | saint-georges
# Processing Record 14 of Set 14 | natal
# Processing Record 15 of Set 14 | belmonte
# Processing Record 16 of Set 14 | formosa do rio preto
# Processing Record 17 of Set 14 | copiapo
# Processing Record 18 of Set 14 | beringovskiy
# Processing Record 19 of Set 14 | shingu
# Processing Record 20 of Set 14 | ayan
# Processing Record 21 of Set 14 | naze
# Processing Record 22 of Set 14 | arbagar
# Processing Record 23 of Set 14 | serramanna
# Processing Record 24 of Set 14 | dolzhanskaya
# Processing Record 25 of Set 14 | mapiripan
# Processing Record 26 of Set 14 | dingzhou
# Processing Record 27 of Set 14 | ulkan
# Processing Record 28 of Set 14 | katubao
# Processing Record 29 of Set 14 | hofn
# Processing Record 30 of Set 14 | marion
# Processing Record 31 of Set 14 | anadyr
# Processing Record 32 of Set 14 | harindanga
# Processing Record 33 of Set 14 | dunkirk
# Processing Record 34 of Set 14 | roura
# Processing Record 35 of Set 14 | zhangye
# Processing Record 36 of Set 14 | prabumulih
# Processing Record 37 of Set 14 | areia branca
# Processing Record 38 of Set 14 | sangmelima
# Processing Record 39 of Set 14 | vrangel
# Processing Record 40 of Set 14 | ossora
# Processing Record 41 of Set 14 | paredon
# Processing Record 42 of Set 14 | karwar
# Processing Record 43 of Set 14 | paso de carrasco
# Processing Record 44 of Set 14 | kyzyl-suu
# Processing Record 45 of Set 14 | ankazoabo
# Processing Record 46 of Set 14 | ukiah
# Processing Record 47 of Set 14 | harqalah
# Processing Record 48 of Set 14 | kaoma
# Processing Record 49 of Set 14 | eureka
# Processing Record 50 of Set 14 | praia da vitoria
# Processing Record 1 of Set 15 | yuncheng
# Processing Record 2 of Set 15 | bogorodskoye
# Processing Record 3 of Set 15 | kahului
# Processing Record 4 of Set 15 | cabinda
# Processing Record 5 of Set 15 | sokolka
# Processing Record 6 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 7 of Set 15 | mizdah
# Processing Record 8 of Set 15 | oranjemund
# Processing Record 9 of Set 15 | mocuba
# Processing Record 10 of Set 15 | hvolsvollur
# Processing Record 11 of Set 15 | saint pete beach
# Processing Record 12 of Set 15 | port-cartier
# Processing Record 13 of Set 15 | hirara
# Processing Record 14 of Set 15 | aklavik
# Processing Record 15 of Set 15 | ulaangom
# Processing Record 16 of Set 15 | saint leonard
# Processing Record 17 of Set 15 | binghamton
# Processing Record 18 of Set 15 | sovetskiy
# Processing Record 19 of Set 15 | basco
# Processing Record 20 of Set 15 | ishigaki
# Processing Record 21 of Set 15 | kurilsk
# Processing Record 22 of Set 15 | dagua
# Processing Record 23 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 15 | rabaul
# Processing Record 25 of Set 15 | uribia
# Processing Record 26 of Set 15 | boa vista
# Processing Record 27 of Set 15 | rocha
# Processing Record 28 of Set 15 | sault sainte marie
# Processing Record 29 of Set 15 | pandamatenga
# Processing Record 30 of Set 15 | sens
# Processing Record 31 of Set 15 | rehoboth
# Processing Record 32 of Set 15 | houlung
# City not found. Skipping...
# Processing Record 33 of Set 15 | priiskovyy
# Processing Record 34 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 35 of Set 15 | thatta
# Processing Record 36 of Set 15 | belyy yar
# Processing Record 37 of Set 15 | muroto
# Processing Record 38 of Set 15 | san antonio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City    Lat     Lng Current Description  Max Temp  Humidity  \
# 0        Rikitea -23.12 -134.97           clear sky     75.99        68
# 1         Bethel  41.37  -73.41     overcast clouds     37.40        86
# 2       Baturaja  -4.13  104.17       broken clouds     74.73        91
# 3         Hobart -42.88  147.33          few clouds     51.01        87
# 4          Pisco -13.70  -76.22       broken clouds     68.00        72
# ..           ...    ...     ...                 ...       ...       ...
# 685   Priiskovyy  51.93  116.63     overcast clouds     28.76        94
# 686       Thatta  24.75   67.92           clear sky     76.87        45
# 687    Belyy Yar  53.60   91.39    scattered clouds     35.60        69
# 688       Muroto  33.28  134.15           clear sky     58.10        62
# 689  San Antonio  29.42  -98.49           clear sky     70.00        28
#
#      Cloudiness  Wind Speed Country
# 0             0        7.94      PF
# 1            90        9.17      US
# 2            77        1.25      ID
# 3            20        4.70      AU
# 4            75        8.05      PE
# ..          ...         ...     ...
# 685         100       10.47      RU
# 686           0        8.84      PK
# 687          40        4.47      RU
# 688           0       15.84      JP
# 689           1        4.27      US
#
# [690 rows x 9 columns]

# %%
city_data_df=city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed","Current Description"]]
city_data_df
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rikitea      PF -23.12 -134.97     75.99        68           0
# 1         Bethel      US  41.37  -73.41     37.40        86          90
# 2       Baturaja      ID  -4.13  104.17     74.73        91          77
# 3         Hobart      AU -42.88  147.33     51.01        87          20
# 4          Pisco      PE -13.70  -76.22     68.00        72          75
# ..           ...     ...    ...     ...       ...       ...         ...
# 685   Priiskovyy      RU  51.93  116.63     28.76        94         100
# 686       Thatta      PK  24.75   67.92     76.87        45           0
# 687    Belyy Yar      RU  53.60   91.39     35.60        69          40
# 688       Muroto      JP  33.28  134.15     58.10        62           0
# 689  San Antonio      US  29.42  -98.49     70.00        28           1
#
#      Wind Speed Current Description
# 0          7.94           clear sky
# 1          9.17     overcast clouds
# 2          1.25       broken clouds
# 3          4.70          few clouds
# 4          8.05       broken clouds
# ..          ...                 ...
# 685       10.47     overcast clouds
# 686        8.84           clear sky
# 687        4.47    scattered clouds
# 688       15.84           clear sky
# 689        4.27           clear sky
#
# [690 rows x 9 columns]

# %%
#Create the output file (CSV).
output_data_file= "weatherpy_database.csv"
#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
