# %%
# Import the requests library.
import requests

# Import the API key.
from configw import weather_api_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import g_key
import time

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#If the city is unique, then we will add it to the cities list.    
    if city not in cities:
            cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description=city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description":city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | peleduy
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | araouane
# Processing Record 5 of Set 1 | igarka
# Processing Record 6 of Set 1 | tigil
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | shanghai
# Processing Record 10 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | adrar
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | marabba
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | hillsborough
# Processing Record 20 of Set 1 | banjar
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | caracuaro
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | opuwo
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | pisco
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | ginir
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | hamilton
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | zhigansk
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | kalga
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | tiznit
# Processing Record 43 of Set 1 | preobrazheniye
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | vorontsovka
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | nantucket
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | tari
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | jian
# Processing Record 8 of Set 2 | pawai
# Processing Record 9 of Set 2 | atambua
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | faya
# Processing Record 12 of Set 2 | mount isa
# Processing Record 13 of Set 2 | gambela
# Processing Record 14 of Set 2 | berlevag
# Processing Record 15 of Set 2 | alofi
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | galesong
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | luchegorsk
# Processing Record 23 of Set 2 | takoradi
# Processing Record 24 of Set 2 | yar-sale
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | lekoni
# Processing Record 27 of Set 2 | hendek
# Processing Record 28 of Set 2 | shelburne
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | broome
# Processing Record 31 of Set 2 | antigonish
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 2 | nouadhibou
# Processing Record 35 of Set 2 | bandiagara
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | harper
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | ayna
# Processing Record 41 of Set 2 | meadow lake
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | rabo de peixe
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | saint-augustin
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | ilhabela
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | rocha
# Processing Record 3 of Set 3 | puerto padre
# Processing Record 4 of Set 3 | harpenden
# Processing Record 5 of Set 3 | stykkisholmur
# Processing Record 6 of Set 3 | damietta
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | toungoo
# City not found. Skipping...
# Processing Record 9 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 3 | vanimo
# Processing Record 11 of Set 3 | bathsheba
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 3 | leshukonskoye
# Processing Record 15 of Set 3 | lumphat
# Processing Record 16 of Set 3 | karlskrona
# Processing Record 17 of Set 3 | te anau
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | tautira
# Processing Record 20 of Set 3 | lethem
# Processing Record 21 of Set 3 | westport
# Processing Record 22 of Set 3 | san patricio
# Processing Record 23 of Set 3 | warner robins
# Processing Record 24 of Set 3 | makakilo city
# Processing Record 25 of Set 3 | praia da vitoria
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | nioro
# Processing Record 28 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 29 of Set 3 | gobabis
# Processing Record 30 of Set 3 | hay river
# Processing Record 31 of Set 3 | malanville
# Processing Record 32 of Set 3 | khani
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | carutapera
# Processing Record 35 of Set 3 | beruwala
# Processing Record 36 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | laiyang
# Processing Record 38 of Set 3 | voh
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | uvira
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | acapulco
# Processing Record 44 of Set 3 | pangnirtung
# Processing Record 45 of Set 3 | douentza
# Processing Record 46 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 3 | duiwelskloof
# Processing Record 48 of Set 3 | buala
# Processing Record 49 of Set 3 | antakya
# Processing Record 50 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | slatinany
# Processing Record 3 of Set 4 | quchan
# Processing Record 4 of Set 4 | pudozh
# Processing Record 5 of Set 4 | peniche
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | sfantu gheorghe
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | leh
# Processing Record 10 of Set 4 | biak
# Processing Record 11 of Set 4 | san pedro
# Processing Record 12 of Set 4 | bua yai
# Processing Record 13 of Set 4 | taoudenni
# Processing Record 14 of Set 4 | bay roberts
# Processing Record 15 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 4 | snyder
# Processing Record 17 of Set 4 | paamiut
# Processing Record 18 of Set 4 | umred
# Processing Record 19 of Set 4 | qasigiannguit
# Processing Record 20 of Set 4 | tharad
# Processing Record 21 of Set 4 | hoquiam
# Processing Record 22 of Set 4 | kawalu
# Processing Record 23 of Set 4 | pevek
# Processing Record 24 of Set 4 | lokosovo
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 4 | mlonggo
# Processing Record 30 of Set 4 | ozernovskiy
# Processing Record 31 of Set 4 | chara
# Processing Record 32 of Set 4 | haapu
# City not found. Skipping...
# Processing Record 33 of Set 4 | hambantota
# Processing Record 34 of Set 4 | avera
# Processing Record 35 of Set 4 | chokurdakh
# Processing Record 36 of Set 4 | uyskoye
# Processing Record 37 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 38 of Set 4 | nishihara
# Processing Record 39 of Set 4 | kyabe
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | vagay
# Processing Record 43 of Set 4 | san jeronimo
# Processing Record 44 of Set 4 | sayyan
# Processing Record 45 of Set 4 | port hedland
# Processing Record 46 of Set 4 | srandakan
# Processing Record 47 of Set 4 | tura
# Processing Record 48 of Set 4 | ulladulla
# Processing Record 49 of Set 4 | krasnomayskiy
# Processing Record 50 of Set 4 | bambous virieux
# Processing Record 1 of Set 5 | yovon
# Processing Record 2 of Set 5 | riyadh
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | esna
# Processing Record 5 of Set 5 | marfino
# Processing Record 6 of Set 5 | lucea
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | avarua
# Processing Record 9 of Set 5 | mizdah
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | autazes
# Processing Record 12 of Set 5 | astorga
# Processing Record 13 of Set 5 | gujan-mestras
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | dunedin
# Processing Record 16 of Set 5 | hilo
# Processing Record 17 of Set 5 | hirara
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | cuencame
# Processing Record 21 of Set 5 | vicuna
# Processing Record 22 of Set 5 | franklin
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | tezu
# Processing Record 25 of Set 5 | matli
# Processing Record 26 of Set 5 | canoinhas
# Processing Record 27 of Set 5 | puerto carreno
# Processing Record 28 of Set 5 | kamenka
# Processing Record 29 of Set 5 | gizeh
# Processing Record 30 of Set 5 | hovd
# Processing Record 31 of Set 5 | martil
# Processing Record 32 of Set 5 | yarmouth
# Processing Record 33 of Set 5 | bosaso
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | portland
# Processing Record 36 of Set 5 | vestmannaeyjar
# Processing Record 37 of Set 5 | koch bihar
# Processing Record 38 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 5 | songkhla
# Processing Record 40 of Set 5 | moranbah
# Processing Record 41 of Set 5 | husavik
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | aktash
# Processing Record 45 of Set 5 | cotonou
# Processing Record 46 of Set 5 | ugoofaaru
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | rohnert park
# Processing Record 49 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 5 | vao
# Processing Record 1 of Set 6 | careiro da varzea
# Processing Record 2 of Set 6 | otane
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | labuhan
# Processing Record 5 of Set 6 | sembe
# Processing Record 6 of Set 6 | amahai
# Processing Record 7 of Set 6 | calvinia
# Processing Record 8 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 6 | cervo
# Processing Record 10 of Set 6 | tortoli
# Processing Record 11 of Set 6 | novonikolayevskiy
# Processing Record 12 of Set 6 | kieta
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | sioux lookout
# Processing Record 16 of Set 6 | aklavik
# Processing Record 17 of Set 6 | ugarcin
# City not found. Skipping...
# Processing Record 18 of Set 6 | newport
# Processing Record 19 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 6 | lockhart
# Processing Record 21 of Set 6 | mastic beach
# Processing Record 22 of Set 6 | port alfred
# Processing Record 23 of Set 6 | ellensburg
# Processing Record 24 of Set 6 | ixtapa
# Processing Record 25 of Set 6 | filingue
# Processing Record 26 of Set 6 | yerbogachen
# Processing Record 27 of Set 6 | soyo
# Processing Record 28 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 6 | sao felix do xingu
# Processing Record 30 of Set 6 | luanda
# Processing Record 31 of Set 6 | jaguarari
# Processing Record 32 of Set 6 | bud
# Processing Record 33 of Set 6 | boyuibe
# Processing Record 34 of Set 6 | oranjestad
# Processing Record 35 of Set 6 | palauig
# Processing Record 36 of Set 6 | queanbeyan
# Processing Record 37 of Set 6 | vardo
# Processing Record 38 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 6 | inhambane
# Processing Record 40 of Set 6 | emerald
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | richards bay
# Processing Record 43 of Set 6 | linxia
# Processing Record 44 of Set 6 | coihaique
# Processing Record 45 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 6 | murray bridge
# Processing Record 47 of Set 6 | asau
# Processing Record 48 of Set 6 | nome
# Processing Record 49 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 6 | san cristobal
# Processing Record 1 of Set 7 | jurado
# Processing Record 2 of Set 7 | stornoway
# Processing Record 3 of Set 7 | katherine
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | dingle
# Processing Record 6 of Set 7 | lebu
# Processing Record 7 of Set 7 | geraldton
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | upernavik
# Processing Record 10 of Set 7 | parker
# Processing Record 11 of Set 7 | itaituba
# Processing Record 12 of Set 7 | chunoyar
# Processing Record 13 of Set 7 | sandwich
# Processing Record 14 of Set 7 | souillac
# Processing Record 15 of Set 7 | carolina
# Processing Record 16 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 7 | verkhoyansk
# Processing Record 19 of Set 7 | mandalgovi
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | sept-iles
# Processing Record 23 of Set 7 | kaeo
# Processing Record 24 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | ponta do sol
# Processing Record 28 of Set 7 | helong
# Processing Record 29 of Set 7 | port blair
# Processing Record 30 of Set 7 | dali
# Processing Record 31 of Set 7 | warwick
# Processing Record 32 of Set 7 | cidreira
# Processing Record 33 of Set 7 | hofn
# Processing Record 34 of Set 7 | muramvya
# Processing Record 35 of Set 7 | misratah
# Processing Record 36 of Set 7 | broken hill
# Processing Record 37 of Set 7 | lhokseumawe
# Processing Record 38 of Set 7 | caravelas
# Processing Record 39 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | port lincoln
# Processing Record 42 of Set 7 | taber
# Processing Record 43 of Set 7 | nalut
# Processing Record 44 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 45 of Set 7 | thunder bay
# Processing Record 46 of Set 7 | kalmunai
# Processing Record 47 of Set 7 | taitung
# Processing Record 48 of Set 7 | natal
# Processing Record 49 of Set 7 | fonte boa
# Processing Record 50 of Set 7 | harsud
# Processing Record 1 of Set 8 | bogande
# Processing Record 2 of Set 8 | ishigaki
# Processing Record 3 of Set 8 | grand gaube
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | mayahi
# Processing Record 6 of Set 8 | huarmey
# Processing Record 7 of Set 8 | kodinsk
# Processing Record 8 of Set 8 | okhotsk
# Processing Record 9 of Set 8 | waingapu
# Processing Record 10 of Set 8 | gambo
# Processing Record 11 of Set 8 | tacna
# Processing Record 12 of Set 8 | niksar
# Processing Record 13 of Set 8 | menongue
# Processing Record 14 of Set 8 | erdenet
# Processing Record 15 of Set 8 | pochutla
# Processing Record 16 of Set 8 | yashkul
# Processing Record 17 of Set 8 | cam ranh
# Processing Record 18 of Set 8 | meulaboh
# Processing Record 19 of Set 8 | buraydah
# Processing Record 20 of Set 8 | santarem
# Processing Record 21 of Set 8 | san martin
# Processing Record 22 of Set 8 | malanje
# Processing Record 23 of Set 8 | sainte-suzanne
# Processing Record 24 of Set 8 | katsuura
# Processing Record 25 of Set 8 | safaga
# Processing Record 26 of Set 8 | arman
# Processing Record 27 of Set 8 | darhan
# Processing Record 28 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 8 | kruisfontein
# Processing Record 30 of Set 8 | kyra
# Processing Record 31 of Set 8 | curvelo
# Processing Record 32 of Set 8 | omboue
# Processing Record 33 of Set 8 | laguna
# Processing Record 34 of Set 8 | teya
# Processing Record 35 of Set 8 | roswell
# Processing Record 36 of Set 8 | isangel
# Processing Record 37 of Set 8 | southbridge
# Processing Record 38 of Set 8 | xinye
# Processing Record 39 of Set 8 | kirsanov
# Processing Record 40 of Set 8 | mount pleasant
# Processing Record 41 of Set 8 | honningsvag
# Processing Record 42 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 43 of Set 8 | evensk
# Processing Record 44 of Set 8 | myitkyina
# Processing Record 45 of Set 8 | belaya gora
# Processing Record 46 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | muscat
# Processing Record 48 of Set 8 | umm kaddadah
# Processing Record 49 of Set 8 | iquique
# Processing Record 50 of Set 8 | necochea
# Processing Record 1 of Set 9 | basse
# Processing Record 2 of Set 9 | lisakovsk
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | kloulklubed
# Processing Record 5 of Set 9 | mwingi
# Processing Record 6 of Set 9 | roros
# Processing Record 7 of Set 9 | dasoguz
# Processing Record 8 of Set 9 | ojuelos de jalisco
# Processing Record 9 of Set 9 | rajmahal
# Processing Record 10 of Set 9 | sisimiut
# Processing Record 11 of Set 9 | ferguson
# Processing Record 12 of Set 9 | qinhuangdao
# Processing Record 13 of Set 9 | vrnograc
# Processing Record 14 of Set 9 | yongan
# Processing Record 15 of Set 9 | curuguaty
# Processing Record 16 of Set 9 | palana
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | rio grande
# Processing Record 19 of Set 9 | naranjito
# Processing Record 20 of Set 9 | yaring
# Processing Record 21 of Set 9 | waipawa
# Processing Record 22 of Set 9 | paita
# Processing Record 23 of Set 9 | furano
# Processing Record 24 of Set 9 | jeremie
# Processing Record 25 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 9 | sambava
# Processing Record 27 of Set 9 | vysokogornyy
# Processing Record 28 of Set 9 | verin
# Processing Record 29 of Set 9 | saint anthony
# Processing Record 30 of Set 9 | tokur
# Processing Record 31 of Set 9 | pangody
# Processing Record 32 of Set 9 | invermere
# Processing Record 33 of Set 9 | luderitz
# Processing Record 34 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | ponta delgada
# Processing Record 37 of Set 9 | moosomin
# Processing Record 38 of Set 9 | waterloo
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | lorengau
# Processing Record 41 of Set 9 | sola
# Processing Record 42 of Set 9 | chaa-khol
# City not found. Skipping...
# Processing Record 43 of Set 9 | touros
# Processing Record 44 of Set 9 | rawson
# Processing Record 45 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 9 | yumen
# Processing Record 47 of Set 9 | havelock
# Processing Record 48 of Set 9 | nelson bay
# Processing Record 49 of Set 9 | verkhnevilyuysk
# Processing Record 50 of Set 9 | tecoanapa
# Processing Record 1 of Set 10 | kadhan
# Processing Record 2 of Set 10 | behshahr
# Processing Record 3 of Set 10 | chingirlau
# Processing Record 4 of Set 10 | ammon
# Processing Record 5 of Set 10 | catuday
# Processing Record 6 of Set 10 | altay
# Processing Record 7 of Set 10 | bilma
# Processing Record 8 of Set 10 | atasu
# Processing Record 9 of Set 10 | hualmay
# Processing Record 10 of Set 10 | miri
# Processing Record 11 of Set 10 | mezen
# Processing Record 12 of Set 10 | gladstone
# Processing Record 13 of Set 10 | fengzhen
# Processing Record 14 of Set 10 | vostok
# Processing Record 15 of Set 10 | caucaia
# Processing Record 16 of Set 10 | shache
# Processing Record 17 of Set 10 | tatishchevo
# Processing Record 18 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 10 | westerland
# Processing Record 20 of Set 10 | saint-georges
# Processing Record 21 of Set 10 | shuyskoye
# Processing Record 22 of Set 10 | abdanan
# Processing Record 23 of Set 10 | kudahuvadhoo
# Processing Record 24 of Set 10 | sacuieu
# City not found. Skipping...
# Processing Record 25 of Set 10 | arlit
# Processing Record 26 of Set 10 | pyapon
# Processing Record 27 of Set 10 | port macquarie
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 10 | boffa
# Processing Record 31 of Set 10 | dumas
# Processing Record 32 of Set 10 | praya
# Processing Record 33 of Set 10 | nabire
# Processing Record 34 of Set 10 | pangkalanbuun
# Processing Record 35 of Set 10 | ketchikan
# Processing Record 36 of Set 10 | bogale
# Processing Record 37 of Set 10 | otjimbingwe
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | takaka
# Processing Record 40 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 10 | ayan
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | obidos
# Processing Record 44 of Set 10 | ganzhou
# Processing Record 45 of Set 10 | oranjemund
# Processing Record 46 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 10 | ughelli
# Processing Record 48 of Set 10 | kouroussa
# Processing Record 49 of Set 10 | palmer
# Processing Record 50 of Set 10 | kapoeta
# Processing Record 1 of Set 11 | mountain home
# Processing Record 2 of Set 11 | moindou
# Processing Record 3 of Set 11 | gonaives
# Processing Record 4 of Set 11 | shimoda
# Processing Record 5 of Set 11 | beloha
# Processing Record 6 of Set 11 | coahuayana
# Processing Record 7 of Set 11 | buin
# Processing Record 8 of Set 11 | tuatapere
# Processing Record 9 of Set 11 | wajir
# Processing Record 10 of Set 11 | chumikan
# Processing Record 11 of Set 11 | whitefish
# Processing Record 12 of Set 11 | komsomolets
# Processing Record 13 of Set 11 | barahona
# Processing Record 14 of Set 11 | sayat
# Processing Record 15 of Set 11 | kununurra
# Processing Record 16 of Set 11 | fare
# Processing Record 17 of Set 11 | abu dhabi
# Processing Record 18 of Set 11 | zyryanovsk
# Processing Record 19 of Set 11 | baykit
# Processing Record 20 of Set 11 | tessalit
# Processing Record 21 of Set 11 | linhares
# Processing Record 22 of Set 11 | oistins
# Processing Record 23 of Set 11 | port-cartier
# Processing Record 24 of Set 11 | bulgan
# Processing Record 25 of Set 11 | neuquen
# Processing Record 26 of Set 11 | pokrovskoye
# Processing Record 27 of Set 11 | san quintin
# Processing Record 28 of Set 11 | anito
# Processing Record 29 of Set 11 | flinders
# Processing Record 30 of Set 11 | devyatka
# City not found. Skipping...
# Processing Record 31 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 11 | lady lake
# Processing Record 33 of Set 11 | watsa
# Processing Record 34 of Set 11 | dunda
# Processing Record 35 of Set 11 | poum
# Processing Record 36 of Set 11 | tilhar
# Processing Record 37 of Set 11 | changji
# Processing Record 38 of Set 11 | bubaque
# Processing Record 39 of Set 11 | bowen
# Processing Record 40 of Set 11 | beyneu
# Processing Record 41 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 11 | aripuana
# Processing Record 44 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 11 | saint-francois
# Processing Record 46 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 48 of Set 11 | havre
# Processing Record 49 of Set 11 | karmana
# City not found. Skipping...
# Processing Record 50 of Set 11 | vredendal
# Processing Record 1 of Set 12 | filadelfia
# Processing Record 2 of Set 12 | rognan
# Processing Record 3 of Set 12 | rondonopolis
# Processing Record 4 of Set 12 | nizhneangarsk
# Processing Record 5 of Set 12 | sibolga
# Processing Record 6 of Set 12 | margate
# Processing Record 7 of Set 12 | solnechnyy
# Processing Record 8 of Set 12 | boldumsaz
# Processing Record 9 of Set 12 | isla aguada
# Processing Record 10 of Set 12 | longhua
# Processing Record 11 of Set 12 | foz
# Processing Record 12 of Set 12 | lozova
# Processing Record 13 of Set 12 | shingu
# Processing Record 14 of Set 12 | kurumkan
# Processing Record 15 of Set 12 | yurginskoye
# Processing Record 16 of Set 12 | medicine hat
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | haines junction
# Processing Record 19 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 12 | chengdu
# Processing Record 21 of Set 12 | luwuk
# Processing Record 22 of Set 12 | ossora
# Processing Record 23 of Set 12 | auki
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | colares
# Processing Record 26 of Set 12 | klaksvik
# Processing Record 27 of Set 12 | oxapampa
# Processing Record 28 of Set 12 | mahon
# Processing Record 29 of Set 12 | salinopolis
# Processing Record 30 of Set 12 | werder
# Processing Record 31 of Set 12 | whitehorse
# Processing Record 32 of Set 12 | general pico
# Processing Record 33 of Set 12 | smithers
# Processing Record 34 of Set 12 | marienburg
# Processing Record 35 of Set 12 | bobon
# Processing Record 36 of Set 12 | cururupu
# Processing Record 37 of Set 12 | santa maria
# Processing Record 38 of Set 12 | maragogi
# Processing Record 39 of Set 12 | maceio
# Processing Record 40 of Set 12 | brunswick
# Processing Record 41 of Set 12 | reconquista
# Processing Record 42 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 43 of Set 12 | atikokan
# Processing Record 44 of Set 12 | chom bung
# City not found. Skipping...
# Processing Record 45 of Set 12 | pierre
# Processing Record 46 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 47 of Set 12 | saint-joseph
# Processing Record 48 of Set 12 | rapid valley
# Processing Record 49 of Set 12 | esso
# Processing Record 50 of Set 12 | lagos
# Processing Record 1 of Set 13 | quimper
# Processing Record 2 of Set 13 | akdepe
# Processing Record 3 of Set 13 | murree
# Processing Record 4 of Set 13 | kahului
# Processing Record 5 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 6 of Set 13 | carbonia
# Processing Record 7 of Set 13 | moron
# Processing Record 8 of Set 13 | marquette
# Processing Record 9 of Set 13 | khed
# Processing Record 10 of Set 13 | lar
# Processing Record 11 of Set 13 | eyrarbakki
# Processing Record 12 of Set 13 | cabedelo
# Processing Record 13 of Set 13 | ahmadpur
# Processing Record 14 of Set 13 | joshimath
# Processing Record 15 of Set 13 | limenaria
# Processing Record 16 of Set 13 | yabelo
# Processing Record 17 of Set 13 | zhicheng
# Processing Record 18 of Set 13 | doha
# Processing Record 19 of Set 13 | noumea
# Processing Record 20 of Set 13 | manaus
# Processing Record 21 of Set 13 | ingham
# Processing Record 22 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 23 of Set 13 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 24 of Set 13 | tambura
# Processing Record 25 of Set 13 | mancio lima
# Processing Record 26 of Set 13 | guerrero negro
# Processing Record 27 of Set 13 | taksimo
# Processing Record 28 of Set 13 | allanmyo
# City not found. Skipping...
# Processing Record 29 of Set 13 | eyl
# Processing Record 30 of Set 13 | kantemirovka
# Processing Record 31 of Set 13 | rauma
# Processing Record 32 of Set 13 | saint leonard
# Processing Record 33 of Set 13 | ballina
# Processing Record 34 of Set 13 | thongwa
# Processing Record 35 of Set 13 | clyde river
# Processing Record 36 of Set 13 | mogadishu
# Processing Record 37 of Set 13 | okato
# Processing Record 38 of Set 13 | abony
# Processing Record 39 of Set 13 | tondano
# Processing Record 40 of Set 13 | san matias
# Processing Record 41 of Set 13 | nedryhayliv
# Processing Record 42 of Set 13 | clarence town
# Processing Record 43 of Set 13 | callaguip
# Processing Record 44 of Set 13 | zhezkazgan
# Processing Record 45 of Set 13 | harlingen
# Processing Record 46 of Set 13 | berdigestyakh
# Processing Record 47 of Set 13 | los llanos de aridane
# Processing Record 48 of Set 13 | chapais
# Processing Record 49 of Set 13 | aksarka
# Processing Record 50 of Set 13 | cervena voda
# Processing Record 1 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 14 | shibata
# Processing Record 3 of Set 14 | istok
# Processing Record 4 of Set 14 | yuancheng
# Processing Record 5 of Set 14 | panjwin
# City not found. Skipping...
# Processing Record 6 of Set 14 | yaan
# Processing Record 7 of Set 14 | boddam
# Processing Record 8 of Set 14 | angoche
# Processing Record 9 of Set 14 | ecoporanga
# Processing Record 10 of Set 14 | gornji milanovac
# Processing Record 11 of Set 14 | tazovskiy
# Processing Record 12 of Set 14 | najran
# Processing Record 13 of Set 14 | mareeba
# Processing Record 14 of Set 14 | bilibino
# Processing Record 15 of Set 14 | belmonte
# Processing Record 16 of Set 14 | imperial beach
# Processing Record 17 of Set 14 | bandarbeyla
# Processing Record 18 of Set 14 | oktyabrskoye
# Processing Record 19 of Set 14 | goulburn
# Processing Record 20 of Set 14 | merke
# Processing Record 21 of Set 14 | canon city
# Processing Record 22 of Set 14 | estevan
# Processing Record 23 of Set 14 | borovskoy
# Processing Record 24 of Set 14 | kilindoni
# Processing Record 25 of Set 14 | arteaga
# Processing Record 26 of Set 14 | codrington
# Processing Record 27 of Set 14 | temerin
# Processing Record 28 of Set 14 | morgan city
# Processing Record 29 of Set 14 | tel aviv-yafo
# Processing Record 30 of Set 14 | north bend
# Processing Record 31 of Set 14 | vestmanna
# Processing Record 32 of Set 14 | calmar
# Processing Record 33 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 14 | mopipi
# Processing Record 35 of Set 14 | puri
# Processing Record 36 of Set 14 | bay-khaak
# Processing Record 37 of Set 14 | huron
# Processing Record 38 of Set 14 | antofagasta
# Processing Record 39 of Set 14 | businga
# Processing Record 40 of Set 14 | awbari
# Processing Record 41 of Set 14 | sinnamary
# Processing Record 42 of Set 14 | raga
# Processing Record 43 of Set 14 | serenje
# Processing Record 44 of Set 14 | burgeo
# Processing Record 45 of Set 14 | nanakuli
# Processing Record 46 of Set 14 | anadyr
# Processing Record 47 of Set 14 | valparaiso
# Processing Record 48 of Set 14 | zonguldak
# Processing Record 49 of Set 14 | east stroudsburg
# Processing Record 50 of Set 14 | rundu
# Processing Record 1 of Set 15 | biltine
# Processing Record 2 of Set 15 | gainesville
# Processing Record 3 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 4 of Set 15 | kapiri mposhi
# Processing Record 5 of Set 15 | borlange
# City not found. Skipping...
# Processing Record 6 of Set 15 | muzhi
# Processing Record 7 of Set 15 | talara
# Processing Record 8 of Set 15 | laramie
# Processing Record 9 of Set 15 | shestakovo
# Processing Record 10 of Set 15 | merrill
# Processing Record 11 of Set 15 | kaoma
# Processing Record 12 of Set 15 | piet retief
# Processing Record 13 of Set 15 | homa bay
# Processing Record 14 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 15 of Set 15 | lima
# Processing Record 16 of Set 15 | lobatse
# Processing Record 17 of Set 15 | chimbarongo
# Processing Record 18 of Set 15 | ornes
# Processing Record 19 of Set 15 | mananjary
# Processing Record 20 of Set 15 | morant bay
# Processing Record 21 of Set 15 | roebourne
# Processing Record 22 of Set 15 | cravo norte
# Processing Record 23 of Set 15 | inzhavino
# Processing Record 24 of Set 15 | xining
# Processing Record 25 of Set 15 | acajutla
# Processing Record 26 of Set 15 | langsa
# Processing Record 27 of Set 15 | korla
# Processing Record 28 of Set 15 | longkou
# Processing Record 29 of Set 15 | locri
# Processing Record 30 of Set 15 | cassia
# Processing Record 31 of Set 15 | seoul
# Processing Record 32 of Set 15 | bisho
# Processing Record 33 of Set 15 | yelizovo
# Processing Record 34 of Set 15 | sistranda
# Processing Record 35 of Set 15 | eydhafushi
# Processing Record 36 of Set 15 | aswan
# Processing Record 37 of Set 15 | tarnogskiy gorodok
# Processing Record 38 of Set 15 | kamaishi
# Processing Record 39 of Set 15 | nieuw amsterdam
# Processing Record 40 of Set 15 | ridgecrest
# Processing Record 41 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 42 of Set 15 | sinfra
# Processing Record 43 of Set 15 | erzin
# Processing Record 44 of Set 15 | minas
# Processing Record 45 of Set 15 | la rioja
# Processing Record 46 of Set 15 | blackwater
# Processing Record 47 of Set 15 | kandrian
# Processing Record 48 of Set 15 | russell
# Processing Record 49 of Set 15 | minab
# Processing Record 50 of Set 15 | maneadero
# Processing Record 1 of Set 16 | dawei
# Processing Record 2 of Set 16 | christchurch
# Processing Record 3 of Set 16 | namatanai
# Processing Record 4 of Set 16 | davila
# Processing Record 5 of Set 16 | port hardy
# Processing Record 6 of Set 16 | jacareacanga
# Processing Record 7 of Set 16 | molina
# Processing Record 8 of Set 16 | hemsedal
# Processing Record 9 of Set 16 | pedasi
# Processing Record 10 of Set 16 | guiyang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City    Lat     Lng Current Description  Max Temp  Humidity  \
# 0           Peleduy  59.63  112.74       broken clouds     14.23        89
# 1    Severo-Kurilsk  50.68  156.12          few clouds     41.76        81
# 2            Albany  42.60  -73.97           clear sky     36.00        70
# 3          Araouane  18.90   -3.53     overcast clouds     78.49        18
# 4            Igarka  67.47   86.58     overcast clouds     19.02        97
# ..              ...    ...     ...                 ...       ...       ...
# 683    Jacareacanga  -6.22  -57.75     overcast clouds     71.13        96
# 684          Molina -35.12  -71.28           clear sky     55.00        81
# 685        Hemsedal  60.86    8.55          light rain     44.01        90
# 686          Pedasi   7.53  -80.03          light rain     78.13        85
# 687         Guiyang  26.58  106.72     overcast clouds     51.80        87
#
#      Cloudiness  Wind Speed Country
# 0            54        6.04      RU
# 1            16       14.79      RU
# 2             0        8.21      US
# 3           100        7.45      ML
# 4           100        4.81      RU
# ..          ...         ...     ...
# 683          86        1.01      BR
# 684           0        2.24      CL
# 685         100        8.37      NO
# 686          93       19.08      PA
# 687          90        8.95      CN
#
# [688 rows x 9 columns]

# %%
city_data_df=city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed","Current Description"]]
city_data_df
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Peleduy      RU  59.63  112.74     14.23        89          54
# 1    Severo-Kurilsk      RU  50.68  156.12     41.76        81          16
# 2            Albany      US  42.60  -73.97     36.00        70           0
# 3          Araouane      ML  18.90   -3.53     78.49        18         100
# 4            Igarka      RU  67.47   86.58     19.02        97         100
# ..              ...     ...    ...     ...       ...       ...         ...
# 683    Jacareacanga      BR  -6.22  -57.75     71.13        96          86
# 684          Molina      CL -35.12  -71.28     55.00        81           0
# 685        Hemsedal      NO  60.86    8.55     44.01        90         100
# 686          Pedasi      PA   7.53  -80.03     78.13        85          93
# 687         Guiyang      CN  26.58  106.72     51.80        87          90
#
#      Wind Speed Current Description
# 0          6.04       broken clouds
# 1         14.79          few clouds
# 2          8.21           clear sky
# 3          7.45     overcast clouds
# 4          4.81     overcast clouds
# ..          ...                 ...
# 683        1.01     overcast clouds
# 684        2.24           clear sky
# 685        8.37          light rain
# 686       19.08          light rain
# 687        8.95     overcast clouds
#
# [688 rows x 9 columns]

# %%
#Create the output file (CSV).
output_data_file= "weatherpy_database.csv"
#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
